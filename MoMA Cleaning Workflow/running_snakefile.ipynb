# %%
! snakemake --cores 1
# Out:
# /Users/reneehuang/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job           count
# ----------  -------
# all               1
# clean_moma        1
# total             2
#
# Select jobs to execute...
#
# [Fri Apr 24 11:37:38 2026]
# rule clean_moma:
#     output: results/moma_snakefile_cleaned.csv
#     jobid: 1
#     reason: Missing output files: results/moma_snakefile_cleaned.csv
#     resources: tmpdir=/var/folders/8b/8mm_4hsx0bvgd8ybbkkv3x380000gn/T
#
# Final shape: (177064, 41)
# Dupes remaining: 0
#
# Top nationalities:
# nationality_clean
# American     83092
# French       24723
# ...
